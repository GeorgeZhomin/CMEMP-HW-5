# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt('output/output.txt', delimiter='\t')

# %%
data
# Out:
# array([[5.00000e+00, 9.23291e-01, 1.74206e-03],
#        [1.00000e+01, 4.91453e-01, 1.74232e-04],
#        [2.00000e+01, 2.46487e-01, 9.92464e-06],
#        [4.00000e+01, 1.23338e-01, 6.07446e-07],
#        [8.00000e+01, 6.16811e-02, 3.77691e-08],
#        [1.60000e+02, 3.08420e-02, 2.35751e-09],
#        [3.20000e+02, 1.54212e-02, 1.47295e-10],
#        [6.40000e+02, 7.71062e-03, 9.25970e-12],
#        [1.28000e+03, 3.85531e-03, 6.59361e-13],
#        [2.56000e+03, 1.92766e-03, 3.65707e-13],
#        [5.12000e+03, 9.63829e-04, 8.69194e-13],
#        [1.02400e+04, 4.81914e-04, 1.36591e-12],
#        [2.04800e+04, 2.40957e-04, 3.13372e-12],
#        [4.09600e+04, 1.20479e-04, 6.21425e-12]])

# %%
fig, ax = plt.subplots()
ax.scatter(data[:,1], data[:,2])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('grid norm')
ax.set_ylabel('error norm estimation')
plt.show()
